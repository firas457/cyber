# %% [markdown]
# # Cisco - Ariel University API Security Detection Challenge 2023
# ## Baseline code
#
#
# ### Imports and global settings

# %%
# Imports, settings and first dataset view
import pandas as pd
import seaborn as sns
import numpy as np
import json

from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

# Set pandas to show all columns when you print a dataframe
pd.set_option('display.max_columns', None)

# Global setting here you choose the dataset number and classification type for the model
dataset_number = 4 # Options are [1, 2, 3, 4]
test_type = 'label' # Options are ['label', 'attack_type']

# Read the json and read it to a pandas dataframe object, you can change these settings
with open(f'./dataset_{str(dataset_number)}_train.json') as file:
    raw_ds = json.load(file)
df = pd.json_normalize(raw_ds, max_level=2)

# Shoe the first five lines of the dataframe to see if everything was read accordingly 
df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                                NaN
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body request.Attack_Tag  \
# 0                         [{}, {}]                NaN
# 1  {"error": "Order ID not found"}                NaN
# 2       {"error": "Access denied"}              LOG4J
# 3         text/html; charset=utf-8                NaN
# 4     {"error": "State not found"}                NaN
#
#   response.headers.Location request.headers.Cookie  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   request.headers.Content-Length response.headers.Set-Cookie  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   request.headers.Upgrade-Insecure-Requests
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                                NaN
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body request.Attack_Tag  \
# 0                         [{}, {}]                NaN
# 1  {"error": "Order ID not found"}                NaN
# 2       {"error": "Access denied"}              LOG4J
# 3         text/html; charset=utf-8                NaN
# 4     {"error": "State not found"}                NaN
#
#   response.headers.Location request.headers.Cookie  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   request.headers.Content-Length response.headers.Set-Cookie  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   request.headers.Upgrade-Insecure-Requests
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
df.plot.hist(x='response.status')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot.hist(x='response.headers.Content-Type')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.countplot(x='response.headers.Content-Type', data=df)
# Out:
# <AxesSubplot: xlabel='response.headers.Content-Type', ylabel='count'>

# %%
sns.histplot(x='response.status', data=df)
# Out:
# <AxesSubplot: xlabel='response.status', ylabel='Count'>

# %%
# Fill the black attack tag lines with "Benign" string
df['request.Attack_Tag'] = df['request.Attack_Tag'].fillna('Benign')
df['attack_type'] = df['request.Attack_Tag']

# This function will be used in the lambda below to iterate over the label columns 
# You can use this snippet to run your own lambda on any data with the apply() method
def categorize(row):  
    if row['request.Attack_Tag'] == 'Benign':
        return 'Benign'
    return 'Malware'

df['label'] = df.apply(lambda row: categorize(row), axis=1)

# After finishing the arrangements we delete the irrelevant column
df.drop('request.Attack_Tag', axis=1, inplace=True)

df
# Out:
#        request.headers.Host  \
# 0            127.0.0.1:5000
# 1            127.0.0.1:5000
# 2            127.0.0.1:5000
# 3            127.0.0.1:5000
# 4            127.0.0.1:5000
# ...                     ...
# 182762       127.0.0.1:5000
# 182763       127.0.0.1:5000
# 182764       127.0.0.1:5000
# 182765       127.0.0.1:5000
# 182766       127.0.0.1:5000
#
#                                request.headers.User-Agent  \
# 0       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# ...                                                   ...
# 182762  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 182763  Mozilla/5.0 (X11; Linux x86_64; rv:28.0) Gecko...
# 182764  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 182765  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 182766  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
#
#                           request.headers.Accept-Encoding  \
# 0                                       gzip, deflate, br
# 1                                       gzip, deflate, br
# 2       gzip, deflate, br${jndi:ldaphabbologinbr.rel7....
# 3                        x-gzip, x-deflate, gzip, deflate
# 4                                       gzip, deflate, br
# ...                                                   ...
# 182762                                  gzip, deflate, br
# 182763                                  gzip, deflate, br
# 182764                                  gzip, deflate, br
# 182765                   x-gzip, x-deflate, gzip, deflate
# 182766                   x-gzip, x-deflate, gzip, deflate
#
#        request.headers.Accept request.headers.Connection  \
# 0                         */*                 keep-alive
# 1                         */*                 keep-alive
# 2                         */*                 keep-alive
# 3                         */*                 keep-alive
# 4                         */*                 keep-alive
# ...                       ...                        ...
# 182762                    */*                 keep-alive
# 182763                    */*                 keep-alive
# 182764                    */*                 keep-alive
# 182765                    */*                 keep-alive
# 182766                    */*                 keep-alive
#
#        request.headers.Sec-Ch-Ua-Platform request.headers.Sec-Ch-Ua-Mobile  \
# 0                               "Windows"                               ?0
# 1                               "Windows"                               ?0
# 2                                     NaN                               ?1
# 3                               "Windows"                               ?1
# 4                               "Windows"                               ?1
# ...                                   ...                              ...
# 182762                                NaN                               ?0
# 182763                                NaN                               ?0
# 182764                                NaN                               ?0
# 182765                          "Windows"                               ?0
# 182766                          "Windows"                               ?0
#
#        request.headers.Accept-Language request.headers.Sec-Fetch-Site  \
# 0                                de-CH                           none
# 1              en-US,en;q=0.9,he;q=0.8                           none
# 2              en-US,en;q=0.9,he;q=0.8                           none
# 3              en-US,en;q=0.9,he;q=0.8                           none
# 4                                de-CH                           none
# ...                                ...                            ...
# 182762                  en-US,en;q=0.5                           none
# 182763                           de-CH                           none
# 182764                           de-CH                           none
# 182765                  en-US,en;q=0.5                           none
# 182766                              de                           none
#
#        request.headers.Sec-Fetch-Mode request.headers.Cache-Control  \
# 0                         same-origin                      no-store
# 1                           websocket                      no-cache
# 2                         same-origin                      no-store
# 3                           websocket                      no-cache
# 4                           websocket                     max-age=0
# ...                               ...                           ...
# 182762                      websocket                      no-cache
# 182763                      websocket                      no-cache
# 182764                    same-origin                     max-age=0
# 182765                    same-origin                      no-store
# 182766                    same-origin                     max-age=0
#
#        request.headers.Sec-Fetch-User request.headers.Sec-Fetch-Dest  \
# 0                                  ?1                       document
# 1                                  ?1                       document
# 2                                  ?1                       document
# 3                                  ?1                       document
# 4                                  ?1                       document
# ...                               ...                            ...
# 182762                             ?1                       document
# 182763                             ?1                       document
# 182764                             ?1                       document
# 182765                             ?1                       document
# 182766                             ?1                       document
#
#                                request.headers.Set-Cookie  \
# 0       ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1       ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2       ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3       ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4       ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
# ...                                                   ...
# 182762  ['ttauth=NPpRHbzfv7BJ5RGB9-oJNl30Ttdc8RYxbuiSe...
# 182763  ['ttauth=Mqfe3PeeakWRmzjsA7MKaNiXmVcbMxMuNQxej...
# 182764  ['cid=-Sp8A62rcqJXADEypNzwtw-iIf9cdHkqMQvKTMNB...
# 182765  ['cid=ERxhJ-aIoFvtHePuy6iitkoC1AdXWOmx2r5Drhpl...
# 182766  ['cid=gJEnE9oujkj7v6KLtnZBBpWODQHkEeAHmm6J_8F6...
#
#                  request.headers.Date request.method  \
# 0       Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1       Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2       Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3       Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4       Sun, 18 Dec 2022 01:23:50 GMT            GET
# ...                               ...            ...
# 182762  Sun, 18 Dec 2022 01:25:40 GMT            GET
# 182763  Sun, 18 Dec 2022 01:19:48 GMT            GET
# 182764  Sun, 18 Dec 2022 01:31:12 GMT            GET
# 182765  Sun, 18 Dec 2022 01:50:29 GMT            GET
# 182766  Sun, 18 Dec 2022 01:59:07 GMT            GET
#
#                                               request.url request.body  \
# 0               http://127.0.0.1:5000/orders/get/random/2
# 1       http://127.0.0.1:5000/orders/check/exists?val=...
# 2       http://127.0.0.1:5000/login/user?username=Rich...
# 3                      http://127.0.0.1:5000/greet/Warren
# 4       http://127.0.0.1:5000/states/Bagdon?resource=R...
# ...                                                   ...          ...
# 182762  http://127.0.0.1:5000/login/user?username=Brue...
# 182763                  http://127.0.0.1:5000/cookielogin
# 182764                        http://127.0.0.1:5000/forum
# 182765    http://127.0.0.1:5000/orders/get/employee_id/35
# 182766  http://127.0.0.1:5000/login/admin/password/bgd...
#
#          response.status response.headers.Content-Type  \
# 0                 200 OK              application/json
# 1          404 NOT FOUND              application/json
# 2       401 UNAUTHORIZED              application/json
# 3                 200 OK      text/html; charset=utf-8
# 4          404 NOT FOUND              application/json
# ...                  ...                           ...
# 182762  401 UNAUTHORIZED              application/json
# 182763            200 OK      text/html; charset=utf-8
# 182764            200 OK      text/html; charset=utf-8
# 182765     404 NOT FOUND              application/json
# 182766   400 BAD REQUEST              application/json
#
#        response.headers.Content-Length  response.status_code  \
# 0                                    8                   200
# 1                                   31                   404
# 2                                   26                   401
# 3                                   22                   200
# 4                                   28                   404
# ...                                ...                   ...
# 182762                              26                   401
# 182763                             104                   200
# 182764                          128212                   200
# 182765                              34                   404
# 182766                              26                   400
#
#                              response.body response.headers.Location  \
# 0                                 [{}, {}]                       NaN
# 1          {"error": "Order ID not found"}                       NaN
# 2               {"error": "Access denied"}                       NaN
# 3                 text/html; charset=utf-8                       NaN
# 4             {"error": "State not found"}                       NaN
# ...                                    ...                       ...
# 182762          {"error": "Access denied"}                       NaN
# 182763            text/html; charset=utf-8                       NaN
# 182764            text/html; charset=utf-8                       NaN
# 182765  {"error": "Employee ID not found"}                       NaN
# 182766          {"error": "Access denied"}                       NaN
#
#                                    request.headers.Cookie  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 182762                                                NaN
# 182763  username=gASVyAAAAAAAAACMCGJ1aWx0aW5zlIwEZXZhb...
# 182764                                                NaN
# 182765                                                NaN
# 182766                                                NaN
#
#        request.headers.Content-Length response.headers.Set-Cookie  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
# ...                               ...                         ...
# 182762                            NaN                         NaN
# 182763                            NaN                         NaN
# 182764                            NaN                         NaN
# 182765                            NaN                         NaN
# 182766                            NaN                         NaN
#
#        request.headers.Upgrade-Insecure-Requests       attack_type    label
# 0                                            NaN            Benign   Benign
# 1                                            NaN            Benign   Benign
# 2                                            NaN             LOG4J  Malware
# 3                                            NaN            Benign   Benign
# 4                                            NaN            Benign   Benign
# ...                                          ...               ...      ...
# 182762                                       NaN     SQL Injection  Malware
# 182763                                       NaN  Cookie Injection  Malware
# 182764                                       NaN               XSS  Malware
# 182765                                       NaN            Benign   Benign
# 182766                                       NaN            Benign   Benign
#
# [182767 rows x 30 columns]

# %%
# Remove all NAN columns or replace with desired string
# This loop iterates over all of the column names which are all NaN
for column in df.columns[df.isna().any()].tolist():
    # df.drop(column, axis=1, inplace=True)
    df[column] = df[column].fillna('None')
    
# If you want to detect columns that may have only some NaN values use this:
# df.loc[:, df.isna().any()].tolist()

df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                               None
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body response.headers.Location  \
# 0                         [{}, {}]                      None
# 1  {"error": "Order ID not found"}                      None
# 2       {"error": "Access denied"}                      None
# 3         text/html; charset=utf-8                      None
# 4     {"error": "State not found"}                      None
#
#   request.headers.Cookie request.headers.Content-Length  \
# 0                   None                           None
# 1                   None                           None
# 2                   None                           None
# 3                   None                           None
# 4                   None                           None
#
#   response.headers.Set-Cookie request.headers.Upgrade-Insecure-Requests  \
# 0                        None                                      None
# 1                        None                                      None
# 2                        None                                      None
# 3                        None                                      None
# 4                        None                                      None
#
#   attack_type    label
# 0      Benign   Benign
# 1      Benign   Benign
# 2       LOG4J  Malware
# 3      Benign   Benign
# 4      Benign   Benign

# %%
features_list = df.columns.to_list()
print(features_list)
# Out:
# ['request.headers.Host', 'request.headers.User-Agent', 'request.headers.Accept-Encoding', 'request.headers.Accept', 'request.headers.Connection', 'request.headers.Sec-Ch-Ua-Platform', 'request.headers.Sec-Ch-Ua-Mobile', 'request.headers.Accept-Language', 'request.headers.Sec-Fetch-Site', 'request.headers.Sec-Fetch-Mode', 'request.headers.Cache-Control', 'request.headers.Sec-Fetch-User', 'request.headers.Sec-Fetch-Dest', 'request.headers.Set-Cookie', 'request.headers.Date', 'request.method', 'request.url', 'request.body', 'response.status', 'response.headers.Content-Type', 'response.headers.Content-Length', 'response.status_code', 'response.body', 'response.headers.Location', 'request.headers.Cookie', 'request.headers.Content-Length', 'response.headers.Set-Cookie', 'request.headers.Upgrade-Insecure-Requests', 'attack_type', 'label']

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import mutual_info_classif


# Select only the feature columns
features_list.remove('attack_type')
features_list.remove('label')

X = df[features_list]

# Preprocess the data to convert non-numeric values to numeric representations
X = X.apply(LabelEncoder().fit_transform)  # Encode categorical features as numeric labels
X = SimpleImputer(strategy='mean').fit_transform(X)  # Impute missing values with the mean

# Extract the target variable
y = df['attack_type']

# Compute mutual information between features and target variable
mi = mutual_info_classif(X, y)

# Print the mutual information values
print(mi)

# Select the top k features based on mutual information
k = 10
top_k_features = np.argsort(mi)[::-1][:k]
print(top_k_features)
# Out:
# [0.         0.03128764 0.18087937 0.         0.00081635 0.27976878
#  0.03610288 0.03563389 0.05324916 0.04266235 0.03653927 0.03119937
#  0.05267599 0.07541386 0.26570931 0.04081581 0.76431533 0.02545501
#  0.25585596 0.18662411 0.66044378 0.25698833 0.46474248 0.17535946
#  0.17333213 0.11514824 0.07312453 0.05611706]
# [16 20 22  5 14 21 18 19  2 23]

# %% [markdown]
# ### Basic dataset label arrangements

# %%
top_k_feature_names = []
for feature_index in top_k_features:
    feature_name = features_list[feature_index]
    top_k_feature_names.append(feature_name)

print(top_k_feature_names)
# Out:
# ['request.url', 'response.headers.Content-Length', 'response.body', 'request.headers.Sec-Ch-Ua-Platform', 'request.headers.Date', 'response.status_code', 'response.status', 'response.headers.Content-Type', 'request.headers.Accept-Encoding', 'response.headers.Location']

# %%
# Create an empty list to store the columns that are not in the top_k_feature_names list
non_top_k_columns = []

# Iterate over the columns in the dataframe
for column in df.columns:
    # If the column is not in the top_k_feature_names list, add it to the non_top_k_columns list
    if column not in top_k_feature_names:
        non_top_k_columns.append(column)

# Print the non_top_k_columns list
print(non_top_k_columns)
# Out:
# ['request.headers.Host', 'request.headers.User-Agent', 'request.headers.Accept', 'request.headers.Connection', 'request.headers.Sec-Ch-Ua-Mobile', 'request.headers.Accept-Language', 'request.headers.Sec-Fetch-Site', 'request.headers.Sec-Fetch-Mode', 'request.headers.Cache-Control', 'request.headers.Sec-Fetch-User', 'request.headers.Sec-Fetch-Dest', 'request.headers.Set-Cookie', 'request.method', 'request.body', 'request.headers.Cookie', 'request.headers.Content-Length', 'response.headers.Set-Cookie', 'request.headers.Upgrade-Insecure-Requests', 'attack_type', 'label']

# %%
df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                               None
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body response.headers.Location  \
# 0                         [{}, {}]                      None
# 1  {"error": "Order ID not found"}                      None
# 2       {"error": "Access denied"}                      None
# 3         text/html; charset=utf-8                      None
# 4     {"error": "State not found"}                      None
#
#   request.headers.Cookie request.headers.Content-Length  \
# 0                   None                           None
# 1                   None                           None
# 2                   None                           None
# 3                   None                           None
# 4                   None                           None
#
#   response.headers.Set-Cookie request.headers.Upgrade-Insecure-Requests  \
# 0                        None                                      None
# 1                        None                                      None
# 2                        None                                      None
# 3                        None                                      None
# 4                        None                                      None
#
#   attack_type    label
# 0      Benign   Benign
# 1      Benign   Benign
# 2       LOG4J  Malware
# 3      Benign   Benign
# 4      Benign   Benign

# %%
#mark this whole code as a comment: # Setting features for further feature extraction by choosing columns
# Some will be "simply" encoded via label encoding and others with HashingVectorizer

# On these headers we will run a "simple" BOW
SIMPLE_HEADERS = ['request.url', 'response.body', 'response.headers.Content-Length', 'response.status', 
'response.status_code', 'request.headers.Cookie', 'response.headers.Location'
                ]

# On these headers we will run HashingVectorizer
COMPLEX_HEADERS = ['request.method', 'request.headers.Content-Length', 'response.headers.Set-Cookie', 
                    ]

COLUMNS_TO_REMOVE = ['request.headers.Host', 'request.headers.User-Agent', 'request.headers.Accept-Encoding',
 'request.headers.Accept', 'request.headers.Connection', 'request.headers.Accept-Language', 'request.headers.Sec-Fetch-Site', 
     'request.headers.Sec-Fetch-Mode', 'request.headers.Sec-Fetch-User', 'request.headers.Sec-Fetch-Dest', 
'request.headers.Set-Cookie', 'request.body', 'response.headers.Content-Type','request.headers.Date']

# This is our main preprocessing function that will iterate over all of the chosen 
# columns and run some feature extraction models
def vectorize_df(df):
    le = LabelEncoder()
    h_vec = HashingVectorizer(n_features=4)

    # Run LabelEncoder on the chosen features
    for column in SIMPLE_HEADERS: 
        df[column] = le.fit_transform(df[column])
    
    # Replace np.nan values with an empty string before running HashingVectorizer
    df = df.fillna('')
    
    # Run HashingVectorizer on the chosen features
    for column in COMPLEX_HEADERS: 
        newHVec = h_vec.fit_transform(df[column])
        df[column] = newHVec.todense()

    # Remove some columns that may be needed.. (Or not, you decide)
    for column in COLUMNS_TO_REMOVE: 
        df.drop(column, axis=1, inplace=True)
    return df


df = vectorize_df(df)
df.head()
# Out:
#   request.headers.Sec-Ch-Ua-Platform request.headers.Sec-Ch-Ua-Mobile  \
# 0                          "Windows"                               ?0
# 1                          "Windows"                               ?0
# 2                               None                               ?1
# 3                          "Windows"                               ?1
# 4                          "Windows"                               ?1
#
#   request.headers.Cache-Control  request.method  request.url  response.status  \
# 0                      no-store             0.0        75190                0
# 1                      no-cache             0.0        63097                5
# 2                      no-store             0.0        52341                4
# 3                      no-cache             0.0        37500                0
# 4                     max-age=0             0.0        75448                5
#
#    response.headers.Content-Length  response.status_code  response.body  \
# 0                             3902                     0            258
# 1                             2585                     5           9586
# 2                             2432                     4           2861
# 3                             2315                     0            260
# 4                             2497                     5           9588
#
#    response.headers.Location  request.headers.Cookie  \
# 0                          2                       0
# 1                          2                       0
# 2                          2                       0
# 3                          2                       0
# 4                          2                       0
#
#    request.headers.Content-Length  response.headers.Set-Cookie  \
# 0                            -1.0                         -1.0
# 1                            -1.0                         -1.0
# 2                            -1.0                         -1.0
# 3                            -1.0                         -1.0
# 4                            -1.0                         -1.0
#
#   request.headers.Upgrade-Insecure-Requests attack_type    label
# 0                                      None      Benign   Benign
# 1                                      None      Benign   Benign
# 2                                      None       LOG4J  Malware
# 3                                      None      Benign   Benign
# 4                                      None      Benign   Benign

# %%
# Memory check (For large datasets sometimes the dataframe will exceed the computers resources)
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182767 entries, 0 to 182766
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   request.headers.Sec-Ch-Ua-Platform         182767 non-null  object
#  1   request.headers.Sec-Ch-Ua-Mobile           182767 non-null  object
#  2   request.headers.Cache-Control              182767 non-null  object
#  3   request.method                             182767 non-null  float64
#  4   request.url                                182767 non-null  int64
#  5   response.status                            182767 non-null  int64
#  6   response.headers.Content-Length            182767 non-null  int64
#  7   response.status_code                       182767 non-null  int64
#  8   response.body                              182767 non-null  int64
#  9   response.headers.Location                  182767 non-null  int64
#  10  request.headers.Cookie                     182767 non-null  int64
#  11  request.headers.Content-Length             182767 non-null  float64
#  12  response.headers.Set-Cookie                182767 non-null  float64
#  13  request.headers.Upgrade-Insecure-Requests  182767 non-null  object
#  14  attack_type                                182767 non-null  object
#  15  label                                      182767 non-null  object
# dtypes: float64(3), int64(7), object(6)
# memory usage: 79.6 MB

# %%
top_k_feature_names = [features_list[i] for i in top_k_features]
print(top_k_feature_names)
# Out:
# ['request.url', 'response.headers.Content-Length', 'response.body', 'request.headers.Sec-Ch-Ua-Platform', 'request.headers.Date', 'response.status_code', 'response.status', 'response.headers.Content-Type', 'request.headers.Accept-Encoding', 'response.headers.Location']

# %%
# Choose the right features
# In our example code we choose all the columns as our feature this can be the right or wrong way to approach the model, you choose.
top_k_features= list(top_k_features)
#features_list = df.columns.to_list()
print(top_k_features)

# Recheck all datatype before training to see we don't have any objects in our features
# In this example our model must get features containing only numbers so we recheck to see if we missed anything during preprocessing
df.dtypes
# Out:
# [16, 20, 22, 5, 14, 21, 18, 19, 2, 23]
# request.headers.Sec-Ch-Ua-Platform            object
# request.headers.Sec-Ch-Ua-Mobile              object
# request.headers.Cache-Control                 object
# request.method                               float64
# request.url                                    int64
# response.status                                int64
# response.headers.Content-Length                int64
# response.status_code                           int64
# response.body                                  int64
# response.headers.Location                      int64
# request.headers.Cookie                         int64
# request.headers.Content-Length               float64
# response.headers.Set-Cookie                  float64
# request.headers.Upgrade-Insecure-Requests     object
# attack_type                                   object
# label                                         object
# dtype: object

# %%
top_k_feature_names = [col for col in top_k_feature_names if col in df.columns]
X = df[top_k_feature_names]


# Preprocess the data to convert non-numeric values to numeric representations
X = X.apply(LabelEncoder().fit_transform)  # Encode categorical features as numeric labels
X = SimpleImputer(strategy='mean').fit_transform(X)  # Impute missing values with the mean

# %% [markdown]
# ## Train test split

# %%
from sklearn.preprocessing import LabelEncoder

# Convert the string labels to numeric labels
le = LabelEncoder()
y = le.fit_transform(y)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1765, random_state=42, stratify=y)

# Print the shapes of the resulting datasets
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (150508, 7) (150508,)
# (32259, 7) (32259,)

# %% [markdown]
# ## Model choosing and fitting

# %%
from sklearn.preprocessing import LabelEncoder

# Convert the string labels to numeric labels
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# Train the model
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Result printout

# %%
# We print our results
sns.set(rc={'figure.figsize':(15,8)})
predictions = clf.predict(X_test)
true_labels = y_test
cf_matrix = confusion_matrix(true_labels, predictions)
clf_report = classification_report(true_labels, predictions, digits=5)
heatmap = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt='g', 
                      xticklabels=np.unique(true_labels), 
                      yticklabels=np.unique(true_labels)) 

# The heatmap is cool but this is the most important result
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0    0.98355   0.99071   0.98712     25292
#            1    1.00000   1.00000   1.00000      1364
#            2    1.00000   1.00000   1.00000       703
#            3    0.48632   0.34842   0.40598       663
#            4    0.99158   0.98468   0.98812       718
#            5    1.00000   1.00000   1.00000       698
#            6    0.98579   0.99213   0.98895      1398
#            7    1.00000   1.00000   1.00000      1423
#
#     accuracy                        0.97864     32259
#    macro avg    0.93090   0.91449   0.92127     32259
# weighted avg    0.97574   0.97864   0.97695     32259

# %%
df['label']
# Out:
# 0          Benign
# 1          Benign
# 2         Malware
# 3          Benign
# 4          Benign
#            ...
# 182762    Malware
# 182763    Malware
# 182764    Malware
# 182765     Benign
# 182766     Benign
# Name: label, Length: 182767, dtype: object

# %%
# Choose the right features
# In our example code we choose all the columns as our feature this can be the right or wrong way to approach the model, you choose.

features_list = df.columns.to_list()
features_list.remove('label')
features_list.remove('attack_type')
print(features_list)

# Recheck all datatype before training to see we don't have any objects in our features
# In this example our model must get features containing only numbers so we recheck to see if we missed anything during preprocessing
df.dtypes
# Out:
# ['request.headers.Sec-Ch-Ua-Platform', 'request.headers.Sec-Ch-Ua-Mobile', 'request.headers.Cache-Control', 'request.method', 'request.url', 'response.status', 'response.headers.Content-Length', 'response.status_code', 'response.body', 'response.headers.Location', 'request.headers.Cookie', 'request.headers.Content-Length', 'response.headers.Set-Cookie', 'request.headers.Upgrade-Insecure-Requests']
# request.headers.Sec-Ch-Ua-Platform            object
# request.headers.Sec-Ch-Ua-Mobile              object
# request.headers.Cache-Control                 object
# request.method                               float64
# request.url                                    int64
# response.status                                int64
# response.headers.Content-Length                int64
# response.status_code                           int64
# response.body                                  int64
# response.headers.Location                      int64
# request.headers.Cookie                         int64
# request.headers.Content-Length               float64
# response.headers.Set-Cookie                  float64
# request.headers.Upgrade-Insecure-Requests     object
# attack_type                                   object
# label                                         object
# dtype: object

# %%
# delete it from complex columns and add it to remove_columns for data set 1 : , 'request.headers.Date'

# %% [markdown]
# # Test

# %%
# Now it's your turn, use the model you have just created :)

# Read the valuation json, preprocess it and run your model 
with open(f'./dataset_{str(dataset_number)}_val.json') as file:
    raw_ds = json.load(file)
    test_df = pd.json_normalize(raw_ds, max_level=2)

# Preprocess the validation dataset, remember that here you don't have the labels
    test_df = vectorize_df(test_df)
    test_df = test_df.apply(pd.to_numeric, errors='coerce')
    test_df = test_df.fillna(0)


# Predict with your model

    X = test_df[top_k_feature_names].to_numpy()
    predictions = clf.predict(X)

# %% [markdown]
# # Save your predictions

# %%
# Save your preditions
enc = LabelEncoder()
np.savetxt(f'./dataset_{str(dataset_number)}_{test_type}_result.txt', enc.fit_transform(predictions), fmt='%2d')
